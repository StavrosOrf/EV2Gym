# %%
import os
#go one directory up
os.chdir("..")

# %%
from EVsSimulator import main_eval
main_eval.eval()
# Out:
# Creating directory: ./plots/ev_city_96_2024-01-20_22-22-36-796705
#
#  Step: 1 | 5  5:15: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 2 | 5  5:30: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 3 | 5  5:45: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 4 | 5  6: 0: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 5 | 5  6:15: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 6 | 5  6:30: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 7 | 5  6:45: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 8 | 5  7: 0: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 9 | 5  7:15: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 10 | 5  7:30: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 11 | 5  7:45: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 12 | 5  8: 0: 0 | 	EVs +1 / -0 | Total: 1 / 10
#
#  Step: 13 | 5  8:15: 0 | 	EVs +0 / -0 | Total: 1 / 10
#
#  Step: 14 | 5  8:30: 0 | 	EVs +0 / -0 | Total: 1 / 10
#
#  Step: 15 | 5  8:45: 0 | 	EVs +0 / -0 | Total: 1 / 10
#
#  Step: 16 | 5  9: 0: 0 | 	EVs +0 / -0 | Total: 1 / 10
#
# ...

# %%
# !dir
# Out:
#  Volume in drive E is SSD_1TB
#  Volume Serial Number is 7085-5FE5
#
#  Directory of e:\GitHub\EVsSimulator\tutorials
#
# 20/01/2024  11:36    <DIR>          .
# 20/01/2024  11:36    <DIR>          ..
# 19/01/2024  23:23           413.273 CreateYourCustomAlgorithm.ipynb
# 20/01/2024  12:01            17.136 Developing an Offline RL algorithm.ipynb
#                2 File(s)        430.409 bytes
#                2 Dir(s)  72.094.003.200 bytes free
