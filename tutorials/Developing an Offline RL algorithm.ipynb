# %%
import os
#go one directory up
os.chdir("..")

# %%
from EVsSimulator import main_eval
main_eval.eval()
# Out:
# Creating directory: ./plots/ev_city_96_2024-01-20_14-03-54-832697
#
#  Step: 1 | 3  5:15: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 2 | 3  5:30: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 3 | 3  5:45: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 4 | 3  6: 0: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 5 | 3  6:15: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 6 | 3  6:30: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 7 | 3  6:45: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 8 | 3  7: 0: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 9 | 3  7:15: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 10 | 3  7:30: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 11 | 3  7:45: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 12 | 3  8: 0: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 13 | 3  8:15: 0 | 	EVs +0 / -0 | Total: 0 / 10
#
#  Step: 14 | 3  8:30: 0 | 	EVs +1 / -0 | Total: 1 / 10
#
#  Step: 15 | 3  8:45: 0 | 	EVs +0 / -0 | Total: 1 / 10
#
#  Step: 16 | 3  9: 0: 0 | 	EVs +0 / -0 | Total: 1 / 10
#
# ...

# %%
# !dir
# Out:
#  Volume in drive E is SSD_1TB
#  Volume Serial Number is 7085-5FE5
#
#  Directory of e:\GitHub\EVsSimulator\tutorials
#
# 20/01/2024  11:36    <DIR>          .
# 20/01/2024  11:36    <DIR>          ..
# 19/01/2024  23:23           413.273 CreateYourCustomAlgorithm.ipynb
# 20/01/2024  12:01            17.136 Developing an Offline RL algorithm.ipynb
#                2 File(s)        430.409 bytes
#                2 Dir(s)  72.094.003.200 bytes free
